# %%
# !pip install assemblyai;
# Out:
# Collecting assemblyai
#   Downloading assemblyai-0.33.0-py3-none-any.whl.metadata (27 kB)
# Collecting httpx>=0.19.0 (from assemblyai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic!=1.10.7,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from assemblyai) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7 in /usr/local/lib/python3.10/dist-packages (from assemblyai) (4.12.2)
# Collecting websockets>=11.0 (from assemblyai)
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (2024.7.4)
# Collecting httpcore==1.* (from httpx>=0.19.0->assemblyai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.19.0->assemblyai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.10.7,>=1.7.0->assemblyai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.10.7,>=1.7.0->assemblyai) (2.20.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.19.0->assemblyai) (1.2.2)
# Downloading assemblyai-0.33.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 4.4 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 9.1 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: websockets, h11, httpcore, httpx, assemblyai
# Successfully installed assemblyai-0.33.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 websockets-13.0.1

# %%
import assemblyai as aai

aai.settings.api_key = "ca7d0ad4d6db4f6bad26de637b524851"

audio_url = "https://github.com/AssemblyAI-Community/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

transcriber = aai.Transcriber()

transcript = transcriber.transcribe(audio_url)

print(transcript.text)
# Out:
# Smoke from hundreds of wildfires in Canada is triggering air quality alerts throughout the US. Skylines from Maine to Maryland to Minnesota are gray and smoggy. And in some places, the air quality warnings include the warning to stay inside. We wanted to better understand what's happening here and why. So he called Peter DiCarlo, an associate professor in the department of Environmental Health and Engineering at Johns Hopkins University. Good morning. Professor. Good morning. So what is it about the conditions right now that have caused this round of wildfires to affect so many people so far away? Well, there's a couple of things. The season has been pretty dry already, and then the fact that we're getting hit in the US is because there's a couple weather systems that are essentially channeling the smoke from those canadian wildfires through Pennsylvania into the mid Atlantic in the northeast and kind of just dropping the smoke there. So what is it in this haze that makes it harmful? And I'm assuming it is harmful. It is. It is. The levels outside right now in Baltimore are considered unhealthy. And most of that is due to what's called particulate matter, which are tiny particles, microscopic, smaller than the width of your hair, that can get into your lungs and impact your respiratory system, your cardiovascular system, and even your neurological, your brain. What makes this particularly harmful? Is it the volume of particulate? Is it something in particular? What is it exactly? Can you just drill down on that a little bit more? Yeah. So the concentration of particulate matter I was looking at, some of the monitors that we have was reaching levels of what are in science peak 150 micrograms per meter cubed, which is more than ten times what the annual average should be in about four times higher than what you're supposed to have on a 24 hours average. And so the concentrations of these particles in the air are just much, much, much higher than we typically see. And exposure to those high levels can lead to a host of health problems. And who is most vulnerable? I noticed that in New York City, for example, they're canceling outdoor activities. And so here it is in the early days of summer, and they have to keep all the kids inside. So who tends to be vulnerable in a situation like this? It's the youngest. So children, obviously, whose bodies are still developing, the elderly, who are, you know, their bodies are more in decline and they're more susceptible to the health impacts of breathing, the poor air quality. And then people who have pre existing health conditions, people with respiratory conditions or heart conditions, can be triggered by high levels of air pollution. Could this get worse? That's a good question. I mean, I think if, and in some areas it's much worse than others, and it just depends on kind of where the smoke is concentrated. I think New York has some of the higher concentrations right now, but that's going to change as that air moves away from the New York area. But over the course of the next few days, we will see different areas being hit at different times with the highest concentrations. I was going to ask you about more fires start burning. I don't expect the concentrations to go up too much higher. I was going to ask you how, and you started to answer this, but how much longer could this last? Forgive me if I'm asking you to speculate, but what do you think? Well, I think the fires are going to burn for a little bit longer, but the key for us in the US is the weather system changing. And so right now it's kind of the weather systems that are pulling that air into our mid Atlantic and northeast region. As those weather systems change and shift, we'll see that smoke going elsewhere and not impact us in this region as much. And so I think that's going to be the defining factor. And I think the next couple of days we're going to see a shift in that weather pattern and start to push the smoke away from whe ...

# %%
print(transcript.words)
# Out:
# [Word(text='Smoke', start=240, end=656, confidence=0.55437, speaker=None), Word(text='from', start=678, end=982, confidence=0.99966, speaker=None), Word(text='hundreds', start=1046, end=1422, confidence=0.99806, speaker=None), Word(text='of', start=1446, end=1582, confidence=1.0, speaker=None), Word(text='wildfires', start=1606, end=2246, confidence=0.92748, speaker=None), Word(text='in', start=2278, end=2446, confidence=0.99775, speaker=None), Word(text='Canada', start=2478, end=3006, confidence=0.99985, speaker=None), Word(text='is', start=3158, end=3446, confidence=0.99061, speaker=None), Word(text='triggering', start=3478, end=3894, confidence=0.999, speaker=None), Word(text='air', start=3942, end=4150, confidence=0.99992, speaker=None), Word(text='quality', start=4190, end=4574, confidence=0.99993, speaker=None), Word(text='alerts', start=4622, end=5054, confidence=0.75095, speaker=None), Word(text='throughout', start=5102, end=5462, confidence=0.99914, speaker=None), Word(text='the', start=5486, end=5622, confidence=1.0, speaker=None), Word(text='US.', start=5646, end=6262, confidence=0.99, speaker=None), Word(text='Skylines', start=6446, end=7206, confidence=0.45355, speaker=None), Word(text='from', start=7238, end=7430, confidence=0.99861, speaker=None), Word(text='Maine', start=7470, end=7910, confidence=0.60378, speaker=None), Word(text='to', start=7990, end=8206, confidence=1.0, speaker=None), Word(text='Maryland', start=8238, end=8622, confidence=0.9158, speaker=None), Word(text='to', start=8686, end=8862, confidence=0.99, speaker=None), Word(text='Minnesota', start=8886, end=9630, confidence=0.96126, speaker=None), Word(text='are', start=9710, end=9926, confidence=0.9951, speaker=None), Word(text='gray', start=9958, end=10166, confidence=0.43, speaker=None), Word(text='and', start=10198, end=10342, confidence=1.0, speaker=None), Word(text='smoggy.', start=10366, end=10998, confidence=0.72705, speaker=None), Word(text='And', start=11094, end=11302, confidence=0.98, speaker=None), Word(text='in', start=11326, end=11486, confidence=0.9984, speaker=None), Word(text='some', start=11518, end=11710, confidence=0.99983, speaker=None), Word(text='places,', start=11750, end=12086, confidence=0.99752, speaker=None), Word(text='the', start=12118, end=12286, confidence=0.99, speaker=None), Word(text='air', start=12318, end=12486, confidence=0.99974, speaker=None), Word(text='quality', start=12518, end=12878, confidence=0.98533, speaker=None), Word(text='warnings', start=12934, end=13350, confidence=0.99324, speaker=None), Word(text='include', start=13390, end=13686, confidence=0.99955, speaker=None), Word(text='the', start=13758, end=13942, confidence=1.0, speaker=None), Word(text='warning', start=13966, end=14190, confidence=0.99609, speaker=None), Word(text='to', start=14230, end=14454, confidence=1.0, speaker=None), Word(text='stay', start=14502, end=14854, confidence=0.9996, speaker=None), Word(text='inside.', start=14942, end=15734, confidence=0.79155, speaker=None), Word(text='We', start=15902, end=16134, confidence=0.99952, speaker=None), Word(text='wanted', start=16142, end=16342, confidence=0.59674, speaker=None), Word(text='to', start=16366, end=16478, confidence=1.0, speaker=None), Word(text='better', start=16494, end=16646, confidence=0.99361, speaker=None), Word(text='understand', start=16678, end=17014, confidence=0.99968, speaker=None), Word(text="what's", start=17102, end=17390, confidence=0.49587, speaker=None), Word(text='happening', start=17430, end=17790, confidence=0.99907, speaker=None), Word(text='here', start=17830, end=17982, confidence=0.99654, speaker=None), Word(text='and', start=18006, end=18166, confidence=1.0, speaker=None), Word(text='why.', start=18198, end=18390, confidence=0.99891, speaker=None), Word(text='So', start=18430, end=18582, confidence=0.98599, speaker=None), Word(text='he', start=18606, end=18718, confidence=0.54289, speaker=None), Word(text='called', start=18734, end=18910, confi ...

# %%
if transcript.status == aai.TranscriptStatus.error:
    print(f"Transcription failed: {transcript.error}")

# %%
config = aai.TranscriptionConfig(speech_model=aai.SpeechModel.nano)
transcriber = aai.Transcriber(config=config)

# %%
# create a new TranscriptionConfig
config = aai.TranscriptionConfig(punctuate=False, format_text=False)

# set the configuration
transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(language_detection=True)

transcriber = aai.Transcriber(config=config)

# %%
print(transcript.json_response["language_confidence"])
# Out:
# None

# %%
config = aai.TranscriptionConfig(
    language_detection=True,
    language_confidence_threshold=0.4
)

# %%
config = aai.TranscriptionConfig(language_code="es")

# %%
config = aai.TranscriptionConfig()
config.set_custom_spelling(
  {
    "Gettleman": ["gettleman"],
    "SQL": ["Sequel"],
  }
)
transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(
  word_boost=["aws", "azure", "google cloud"],
  boost_param="high"
)

transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(dual_channel=True)

transcriber = aai.Transcriber(config=config)
transcript = transcriber.transcribe(audio_url)

print(transcript.utterances)
# Out:
# [Utterance(text="Smoke from hundreds of wildfires in Canada is triggering air quality alerts throughout the US. Skylines from Maine to Maryland to Minnesota are gray and smoggy. And in some places, the air quality warnings include the warning to stay inside. We wanted to better understand what's happening here and why. So he called Peter DiCarlo, an associate professor in the department of Environmental Health and Engineering at Johns Hopkins University. Good morning. Professor.", start=240, end=26770, confidence=0.9189623287671229, speaker='1', channel='1', words=[UtteranceWord(text='Smoke', start=240, end=656, confidence=0.55437, speaker='1', channel='1'), UtteranceWord(text='from', start=678, end=982, confidence=0.99966, speaker='1', channel='1'), UtteranceWord(text='hundreds', start=1046, end=1422, confidence=0.99808, speaker='1', channel='1'), UtteranceWord(text='of', start=1446, end=1582, confidence=1.0, speaker='1', channel='1'), UtteranceWord(text='wildfires', start=1606, end=2246, confidence=0.92716, speaker='1', channel='1'), UtteranceWord(text='in', start=2278, end=2446, confidence=0.99776, speaker='1', channel='1'), UtteranceWord(text='Canada', start=2478, end=3006, confidence=0.99985, speaker='1', channel='1'), UtteranceWord(text='is', start=3158, end=3446, confidence=0.99061, speaker='1', channel='1'), UtteranceWord(text='triggering', start=3478, end=3894, confidence=0.99902, speaker='1', channel='1'), UtteranceWord(text='air', start=3942, end=4150, confidence=0.99992, speaker='1', channel='1'), UtteranceWord(text='quality', start=4190, end=4574, confidence=0.99993, speaker='1', channel='1'), UtteranceWord(text='alerts', start=4622, end=5054, confidence=0.75104, speaker='1', channel='1'), UtteranceWord(text='throughout', start=5102, end=5462, confidence=0.99914, speaker='1', channel='1'), UtteranceWord(text='the', start=5486, end=5622, confidence=1.0, speaker='1', channel='1'), UtteranceWord(text='US.', start=5646, end=6262, confidence=0.99, speaker='1', channel='1'), UtteranceWord(text='Skylines', start=6446, end=7206, confidence=0.45355, speaker='1', channel='1'), UtteranceWord(text='from', start=7238, end=7430, confidence=0.99863, speaker='1', channel='1'), UtteranceWord(text='Maine', start=7470, end=7910, confidence=0.59996, speaker='1', channel='1'), UtteranceWord(text='to', start=7990, end=8206, confidence=1.0, speaker='1', channel='1'), UtteranceWord(text='Maryland', start=8238, end=8622, confidence=0.9158, speaker='1', channel='1'), UtteranceWord(text='to', start=8686, end=8862, confidence=0.99, speaker='1', channel='1'), UtteranceWord(text='Minnesota', start=8886, end=9630, confidence=0.96181, speaker='1', channel='1'), UtteranceWord(text='are', start=9710, end=9926, confidence=0.9951, speaker='1', channel='1'), UtteranceWord(text='gray', start=9958, end=10166, confidence=0.43, speaker='1', channel='1'), UtteranceWord(text='and', start=10198, end=10342, confidence=1.0, speaker='1', channel='1'), UtteranceWord(text='smoggy.', start=10366, end=10998, confidence=0.72865, speaker='1', channel='1'), UtteranceWord(text='And', start=11094, end=11302, confidence=0.98, speaker='1', channel='1'), UtteranceWord(text='in', start=11326, end=11486, confidence=0.9984, speaker='1', channel='1'), UtteranceWord(text='some', start=11518, end=11710, confidence=0.99983, speaker='1', channel='1'), UtteranceWord(text='places,', start=11750, end=12086, confidence=0.99753, speaker='1', channel='1'), UtteranceWord(text='the', start=12118, end=12286, confidence=0.99, speaker='1', channel='1'), UtteranceWord(text='air', start=12318, end=12486, confidence=0.99974, speaker='1', channel='1'), UtteranceWord(text='quality', start=12518, end=12878, confidence=0.9851, speaker='1', channel='1'), UtteranceWord(text='warnings', start=12934, end=13350, confidence=0.99327, speaker='1', channel='1'), UtteranceWord(text='include', start=13390, end=13686, confidence=0.99955, speaker='1', channel='1'), UtteranceWord(text='the', start=13758, end=13 ...

# %%
srt = transcript.export_subtitles_srt()
srt = transcript.export_subtitles_srt(chars_per_caption=32)

vtt = transcript.export_subtitles_vtt()
vtt = transcript.export_subtitles_vtt(chars_per_caption=32)

# %%
sentences = transcript.get_sentences()
for sentence in sentences:
  print(sentence.text)

paragraphs = transcript.get_paragraphs()
for paragraph in paragraphs:
  print(paragraph.text)
# Out:
# Smoke Smoke from from hundreds hundreds of of wildfires wildfires in in Canada Canada is is triggering triggering air air quality quality alerts alerts throughout throughout the the US.
# US.
# Skylines Skylines from from Maine Maine to to Maryland Maryland to to Minnesota Minnesota are are gray gray and and smoggy.
# smoggy.
# And And in in some some places, places, the the air air quality quality warnings warnings include include the the warning warning to to stay stay inside.
# inside.
# We We wanted wanted to to better better understand understand what's what's happening happening here here and and why.
# why.
# So So he he called called Peter Peter DiCarlo, DiCarlo, an an associate associate professor professor in in the the department department of of Environmental Environmental Health Health and and Engineering Engineering at at Johns Johns Hopkins Hopkins University.
# University.
# Good Good morning.
# morning.
# Professor.
# Professor.
# Good Good morning.
# morning.
# So So what what is is it it about about the the conditions conditions right right now now that that have have caused caused this this round round of of wildfires wildfires to to affect affect so so many many people people so so far far away?
# away?
# Well, Well, there's there's a a couple couple of of things.
# things.
# The The season season has has been been pretty pretty dry dry already, already, and and then then the the fact fact that that we're we're getting getting hit hit in in the the US US is is because because there's there's a a couple couple weather weather systems systems that that are are essentially essentially channeling channeling the the smoke smoke from from those those canadian canadian wildfires wildfires through through Pennsylvania Pennsylvania into into the the mid mid Atlantic Atlantic in in the the northeast northeast and and kind kind of of just just dropping dropping the the smoke smoke there.
# there.
# So So what what is is it it in in this this haze haze that that makes makes it it harmful?
# harmful?
# And And I'm I'm assuming assuming it it is is harmful.
# harmful.
# It It is.
# is.
# It It is.
# is.
# The The levels levels outside outside right right now now in in Baltimore Baltimore are are considered considered unhealthy.
# unhealthy.
# And And most most of of that that is is due due to to what's what's called called particulate particulate matter, matter, which which are are tiny tiny particles, particles, microscopic, microscopic, smaller smaller than than the the width width of of your your hair, hair, that that can can get get into into your your lungs lungs and and impact impact your your respiratory respiratory system, system, your your cardiovascular cardiovascular system, system, and and even even your your neurological, neurological, your your brain.
# brain.
# What What makes makes this this particularly particularly harmful?
# harmful?
# Is Is it it the the volume volume of of particulate?
# particulate?
# Is Is it it something something in in particular?
# particular?
# What What is is it it exactly?
# exactly?
# Can Can you you just just drill drill down down on on that that a a little little bit bit more?
# more?
# Yeah.
# Yeah.
# So So the the concentration concentration of of particulate particulate matter matter I I was was looking looking at, at, some some of of the the monitors monitors that that we we have have was was reaching reaching levels levels of of what what are.
# are.
# In In science science peak peak 150 150 micrograms micrograms per per meter meter cubed, cubed, which which is is more more than than ten ten times times what what the the annual annual average average should should be be in in about.
# about.
# Four Four times times higher higher than than what what you're you're supposed supposed to to have have on on a a 24 24 hours hours average.
# average.
# And And so so the the concentrations concentrations of of these these particles particles in in the the air air are are just just much, much, much, much, much much higher higher than than we we typically typically see.
# see.
# And And exposure exposure to to those those high high levels levels can can lead lead to to a a host host of of health health problems.
# problems.
# And And who who is is most most vulnerable?
# vulnerable?
# I I noticed noticed that that in in New New York York City, City, for for example, example, they're they're canceling canceling outdoor outdoor activities.
# activities.
# And And so so here here it it is is in in the the early early days days of of summer, summer, and and they they have have to to keep keep all all the the kids kids inside.
# inside.
# So So who who tends tends to to be be vulnerable vulnerable in in a a situation situation like like this?
# this?
# It's It's the the youngest.
# youngest.
# So So children, children, obviously.
# obviously.
# Whose Whose bodies bodies are are still still developing, developing, the the elderly, elderly, who who are, are, you you know, know, their their bodies bodies are are more more in in decline decline and and they're they're more more susceptible susceptible to to the the health health impacts impacts of of breathing, breathing, the the poor poor air air quality.
# quality.
# And And then then people people who who have have pre pre existing existing health health conditions, conditions, people people with with respiratory respiratory conditions conditions or or heart heart conditions, conditions, can can be be triggered triggered by by high high levels levels of of air air pollution.
# pollution.
# Could Could this this get get worse?
# worse?
# That's That's a a good good question.
# question.
# I I mean, mean, I I think think if, if, and and in in some some areas areas it's it's much much worse worse than than others, others, and and it it just just depends depends on on kind kind of of where where the the smoke smoke is is concentrated.
# concentrated.
# I I think think New New York York has has some some of of the the higher higher concentrations concentrations right right now, now, but but that's that's going going to to change change as as that that air air moves moves away away from from the the New New York York area.
# area.
# But But over over the the course course of of the the next next few few days, days, we we will will see see different different areas areas being being hit hit at at different different times times with with the the highest highest concentrations.
# concentrations.
# I I was was going going to to ask ask you you about about more more fires fires start start burning.
# burning.
# I I don't don't expect expect the the concentrations concentrations to to go go up up too too much much higher.
# higher.
# I I was was going going to to ask ask you you how, how, and and you you started started to to answer answer this, this, but but how how much much longer longer could could this this last?
# last?
# Forgive Forgive me me if if I'm I'm asking asking you you to to speculate, speculate, but but what what do do you you think?
# think?
# Well, Well, I I think think the the fires fires are are going going to to burn burn for for a a little little bit bit longer, longer, but but the the key key for for us us in in the the US US is is the the weather weather system system changing.
# changing.
# And And so so right right now now it's it's kind kind of of the the weather weather systems systems that that are are pulling pulling that that air air into into our.
# our.
# Mid Mid Atlantic Atlantic and and northeast northeast region.
# region.
# As As those those weather weather systems systems change change and and shift, shift, we'll we'll see see that that smoke smoke going going elsewhere elsewhere and and not not impact impact us us in in this this region region as as much.
# much.
# And And so so I I think think that's that's going going to to be be the the defining defining factor.
# factor.
# And And I I think think the the next next couple couple of of days days we're we're going going to to see see a a shift shift in in that that weather weather pattern pattern and and start start to to push push the the smoke smoke away away from from where where we we are.
# are.
# And And finally, finally, with with the the impacts impacts of of climate climate change, change, we we are are seeing seeing more more wildfires.
# wildfires.
# Will Will we we be be seeing seeing more more of of these these kinds kinds of of wide wide ranging.
# ranging.
# Air Air quality quality consequences consequences or or circumstances?
# circumstances?
# I I mean, mean, that that is is one one of of the the predictions.
# predictions.
# For For climate climate change.
# change.
# Looking Looking into into the the future, future, the the fire fire season season is is starting starting earlier earlier and and lasting lasting longer, longer, and and we're we're seeing seeing more more frequent frequent fires.
# fires.
# So, So, yeah, yeah, this this is is probably probably something something that that we'll we'll be be seeing seeing more more frequently.
# frequently.
# This This tends tends to to be be much much more more of of an an issue issue in in the the western western Us.
# Us.
# So So the the eastern eastern us us getting getting hit hit right right now now is is a a little little bit bit new.
# new.
# But, But, yeah, yeah, I I think think with with climate climate change change moving moving forward, forward, this this is is something something that that is is going going to to happen happen more more frequently.
# frequently.
# That's That's Peter Peter DiCarlo, DiCarlo, associate associate professor professor in in the the department department of of Environmental Environmental Health Health and and engineering engineering at at Johns Johns Hopkins Hopkins University.
# University.
# Professor Professor de de Carlo, Carlo, thanks thanks so so much much for for joining joining us us and and sharing sharing this this expertise expertise with with us.
# us.
# Thank Thank you you for for having having me.
# me.
# Smoke Smoke from from hundreds hundreds of of wildfires wildfires in in Canada Canada is is triggering triggering air air quality quality alerts alerts throughout throughout the the US. US. Skylines Skylines from from Maine Maine to to Maryland Maryland to to Minnesota Minnesota are are gray gray and and smoggy. smoggy. And And in in some some places, places, the the air air quality quality warnings warnings include include the the warning warning to to stay stay inside.
# inside. We We wanted wanted to to better better understand understand what's what's happening happening here here and and why. why. So So he he called called Peter Peter DiCarlo, DiCarlo, an an associate associate professor professor in in the the department department of of Environmental Environmental Health Health and and Engineering Engineering at at Johns Johns Hopkins Hopkins University. University.
# Good Good morning. morning. Professor. Professor. Good Good morning.
# morning. So So what what is is it it about about the the conditions conditions right right now now that that have have caused caused this this round round of of wildfires wildfires to to affect affect so so many many people people so so far far away? away? Well, Well, there's there's a a couple couple of of things. things.
# The The season season has has been been pretty pretty dry dry already, already, and and then then the the fact fact that that we're we're getting getting hit hit in in the the US US is is because because there's there's a a couple couple weather weather systems systems that that are are essentially essentially channeling channeling the the smoke smoke from from those those canadian canadian wildfires wildfires through through Pennsylvania Pennsylvania into into the the mid mid Atlantic Atlantic in in the the northeast northeast and and kind kind of of just just dropping dropping the the smoke smoke there. there. So So what what is is it it in in this this haze haze that that makes makes it it harmful? harmful? And And I'm I'm assuming assuming it it is is harmful.
# harmful. It It is. is. It It is. is.
# The The levels levels outside outside right right now now in in Baltimore Baltimore are are considered considered unhealthy. unhealthy. And And most most of of that that is is due due to to what's what's called called particulate particulate matter, matter, which which are are tiny tiny particles, particles, microscopic, microscopic, smaller smaller than than the the width width of of your your hair, hair, that that can can get get into into your your lungs lungs and and impact impact your your respiratory respiratory system, system, your your cardiovascular cardiovascular system, system, and and even even your your neurological, neurological, your your brain. brain. What What makes makes this this particularly particularly harmful?
# harmful? Is Is it it the the volume volume of of particulate? particulate? Is Is it it something something in in particular? particular?
# What What is is it it exactly? exactly? Can Can you you just just drill drill down down on on that that a a little little bit bit more? more? Yeah.
# Yeah. So So the the concentration concentration of of particulate particulate matter matter I I was was looking looking at, at, some some of of the the monitors monitors that that we we have have was was reaching reaching levels levels of of what what are. are. In In science science peak peak 150 150 micrograms micrograms per per meter meter cubed, cubed, which which is is more more than than ten ten times times what what the the annual annual average average should should be be in in about. about.
# Four Four times times higher higher than than what what you're you're supposed supposed to to have have on on a a 24 24 hours hours average. average. And And so so the the concentrations concentrations of of these these particles particles in in the the air air are are just just much, much, much, much, much much higher higher than than we we typically typically see. see. And And exposure exposure to to those those high high levels levels can can lead lead to to a a host host of of health health problems.
# problems. And And who who is is most most vulnerable? vulnerable? I I noticed noticed that that in in New New York York City, City, for for example, example, they're they're canceling canceling outdoor outdoor activities. activities.
# And And so so here here it it is is in in the the early early days days of of summer, summer, and and they they have have to to keep keep all all the the kids kids inside. inside. So So who who tends tends to to be be vulnerable vulnerable in in a a situation situation like like this? this? It's It's the the youngest.
# youngest. So So children, children, obviously. obviously. Whose Whose bodies bodies are are still still developing, developing, the the elderly, elderly, who who are, are, you you know, know, their their bodies bodies are are more more in in decline decline and and they're they're more more susceptible susceptible to to the the health health impacts impacts of of breathing, breathing, the the poor poor air air quality. quality.
# And And then then people people who who have have pre pre existing existing health health conditions, conditions, people people with with respiratory respiratory conditions conditions or or heart heart conditions, conditions, can can be be triggered triggered by by high high levels levels of of air air pollution. pollution. Could Could this this get get worse? worse?
# That's That's a a good good question. question. I I mean, mean, I I think think if, if, and and in in some some areas areas it's it's much much worse worse than than others, others, and and it it just just depends depends on on kind kind of of where where the the smoke smoke is is concentrated. concentrated. I I think think New New York York has has some some of of the the higher higher concentrations concentrations right right now, now, but but that's that's going going to to change change as as that that air air moves moves away away from from the the New New York York area.
# area. But But over over the the course course of of the the next next few few days, days, we we will will see see different different areas areas being being hit hit at at different different times times with with the the highest highest concentrations. concentrations. I I was was going going to to ask ask you you about about more more fires fires start start burning. burning.
# I I don't don't expect expect the the concentrations concentrations to to go go up up too too much much higher. higher. I I was was going going to to ask ask you you how, how, and and you you started started to to answer answer this, this, but but how how much much longer longer could could this this last? last? Forgive Forgive me me if if I'm I'm asking asking you you to to speculate, speculate, but but what what do do you you think?
# think? Well, Well, I I think think the the fires fires are are going going to to burn burn for for a a little little bit bit longer, longer, but but the the key key for for us us in in the the US US is is the the weather weather system system changing. changing. And And so so right right now now it's it's kind kind of of the the weather weather systems systems that that are are pulling pulling that that air air into into our. our.
# Mid Mid Atlantic Atlantic and and northeast northeast region. region. As As those those weather weather systems systems change change and and shift, shift, we'll we'll see see that that smoke smoke going going elsewhere elsewhere and and not not impact impact us us in in this this region region as as much. much. And And so so I I think think that's that's going going to to be be the the defining defining factor.
# factor. And And I I think think the the next next couple couple of of days days we're we're going going to to see see a a shift shift in in that that weather weather pattern pattern and and start start to to push push the the smoke smoke away away from from where where we we are. are. And And finally, finally, with with the the impacts impacts of of climate climate change, change, we we are are seeing seeing more more wildfires. wildfires.
# Will Will we we be be seeing seeing more more of of these these kinds kinds of of wide wide ranging. ranging. Air Air quality quality consequences consequences or or circumstances? circumstances? I I mean, mean, that that is is one one of of the the predictions.
# predictions. For For climate climate change. change. Looking Looking into into the the future, future, the the fire fire season season is is starting starting earlier earlier and and lasting lasting longer, longer, and and we're we're seeing seeing more more frequent frequent fires. fires.
# So, So, yeah, yeah, this this is is probably probably something something that that we'll we'll be be seeing seeing more more frequently. frequently. This This tends tends to to be be much much more more of of an an issue issue in in the the western western Us. Us. So So the the eastern eastern us us getting getting hit hit right right now now is is a a little little bit bit new.
# new. But, But, yeah, yeah, I I think think with with climate climate change change moving moving forward, forward, this this is is something something that that is is going going to to happen happen more more frequently. frequently. That's That's Peter Peter DiCarlo, DiCarlo, associate associate professor professor in in the the department department of of Environmental Environmental Health Health and and engineering engineering at at Johns Johns Hopkins Hopkins University. University.
# Professor Professor de de Carlo, Carlo, thanks thanks so so much much for for joining joining us us and and sharing sharing this this expertise expertise with with us. us. Thank Thank you you for for having having me. me.

# %%
config = aai.TranscriptionConfig(disfluencies=True)

transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(filter_profanity=True)

transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(
  audio_start_from=5000,  # The start time of the transcription in milliseconds
  audio_end_at=15000  # The end time of the transcription in milliseconds
)

transcriber = aai.Transcriber(config=config)

# %%
config = aai.TranscriptionConfig(speech_threshold=0.1)

transcriber = aai.Transcriber(config=config)

# %%
# Set the words you want to search for
words = ["foo", "bar", "foo bar", "42"]

matches = transcript.word_search(words)

for match in matches:
    print(f"Found '{match.text}' {match.count} times in the transcript")
